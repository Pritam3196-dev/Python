# %%
import pandas as pd

# %%
names=['Tanmay', 'Sanjay', 'Ambika', 'Ebi', 'Prajakta','Vishal','Yatin','Natraj']
age=[25,24,28,22,26,31,25,36]
city=['Pune','Bangalore','Chennai','Dehradun','Mumbai','Pune','Chandigarh','Delhi']

# %%
df=pd.DataFrame({'Name':names,'Age':age,'City':city})
df
# Out:
#        Name  Age        City
# 0    Tanmay   25        Pune
# 1    Sanjay   24   Bangalore
# 2    Ambika   28     Chennai
# 3       Ebi   22    Dehradun
# 4  Prajakta   26      Mumbai
# 5    Vishal   31        Pune
# 6     Yatin   25  Chandigarh
# 7    Natraj   36       Delhi

# %%
emp={
    'emp_1':{'Name':'Yatin',
             'Age':25,
             'City':'Pune'},
    
    'emp_2':{'Name':'Piyush',
             'Age':28,
             'City':'Delhi'},
    
    'emp_3':{'Name':'Akshay',
             'Age':27,
             'City':'Dehradun'},
    
    'emp_4':{'Name':'Yushma',
             'Age':24,
             'City':'Bangalore'},
    
    'emp_5':{'Name':'Vaishnavi',
             'Age':28,
             'City':'Madurai'}
    
    }
print(emp)
# Out:
# {'emp_1': {'Name': 'Yatin', 'Age': 25, 'City': 'Pune'}, 'emp_2': {'Name': 'Piyush', 'Age': 28, 'City': 'Delhi'}, 'emp_3': {'Name': 'Akshay', 'Age': 27, 'City': 'Dehradun'}, 'emp_4': {'Name': 'Yushma', 'Age': 24, 'City': 'Bangalore'}, 'emp_5': {'Name': 'Vaishnavi', 'Age': 28, 'City': 'Madurai'}}

# %%
df2=pd.DataFrame(emp).T
df2
# Out:
#             Name Age       City
# emp_1      Yatin  25       Pune
# emp_2     Piyush  28      Delhi
# emp_3     Akshay  27   Dehradun
# emp_4     Yushma  24  Bangalore
# emp_5  Vaishnavi  28    Madurai

# %% [markdown]
# # Slicing of a dataframe

# %%
# df.iloc[row_slicing]
# df.iloc[start:stop:step]

# df.iloc[row_slicing,col_slicing]
# df.iloc[start:stop:step,start:stop:step]


# df.loc[row_slicing]
# df.loc[start:stop:step]

# df.loc[row_slicing,col_slicing]
# df.loc[start:stop:step,start:stop:step]

# %%
df
# Out:
#        Name  Age        City
# 0    Tanmay   25        Pune
# 1    Sanjay   24   Bangalore
# 2    Ambika   28     Chennai
# 3       Ebi   22    Dehradun
# 4  Prajakta   26      Mumbai
# 5    Vishal   31        Pune
# 6     Yatin   25  Chandigarh
# 7    Natraj   36       Delhi

# %%
# Fetch the first 3 rows

df.iloc[0:3]
# Out:
#      Name  Age       City
# 0  Tanmay   25       Pune
# 1  Sanjay   24  Bangalore
# 2  Ambika   28    Chennai

# %%
# Fetch the first 4 row and the alternate columns

df.iloc[0:4,::2]
# Out:
#      Name       City
# 0  Tanmay       Pune
# 1  Sanjay  Bangalore
# 2  Ambika    Chennai
# 3     Ebi   Dehradun

# %%
# Get the first two columns

df.iloc[::,0:2]
# Out:
#        Name  Age
# 0    Tanmay   25
# 1    Sanjay   24
# 2    Ambika   28
# 3       Ebi   22
# 4  Prajakta   26
# 5    Vishal   31
# 6     Yatin   25
# 7    Natraj   36

# %%
# Reverse the rows

df.iloc[::-1]
# Out:
#        Name  Age        City
# 7    Natraj   36       Delhi
# 6     Yatin   25  Chandigarh
# 5    Vishal   31        Pune
# 4  Prajakta   26      Mumbai
# 3       Ebi   22    Dehradun
# 2    Ambika   28     Chennai
# 1    Sanjay   24   Bangalore
# 0    Tanmay   25        Pune

# %%
# Reverse the columns

df.iloc[::,::-1]
# Out:
#          City  Age      Name
# 0        Pune   25    Tanmay
# 1   Bangalore   24    Sanjay
# 2     Chennai   28    Ambika
# 3    Dehradun   22       Ebi
# 4      Mumbai   26  Prajakta
# 5        Pune   31    Vishal
# 6  Chandigarh   25     Yatin
# 7       Delhi   36    Natraj

# %%
df2
# Out:
#             Name Age       City
# emp_1      Yatin  25       Pune
# emp_2     Piyush  28      Delhi
# emp_3     Akshay  27   Dehradun
# emp_4     Yushma  24  Bangalore
# emp_5  Vaishnavi  28    Madurai

# %%
# Fetch the first 4 rows

df2.iloc[0:4]
# Out:
#          Name Age   City
# emp_1   Yatin  25   Pune
# emp_2  Piyush  28  Delhi

# %%
df2.loc['emp_1':'emp_4']
# Out:
#          Name Age       City
# emp_1   Yatin  25       Pune
# emp_2  Piyush  28      Delhi
# emp_3  Akshay  27   Dehradun
# emp_4  Yushma  24  Bangalore

# %%
# Fetch all the rows and the City column

df2.loc[::,['City']]
# Out:
#             City
# emp_1       Pune
# emp_2      Delhi
# emp_3   Dehradun
# emp_4  Bangalore
# emp_5    Madurai

# %%
# Fetch the City and Age column

df2.loc[::,['City','Age','Name']]
# Out:
#             City Age       Name
# emp_1       Pune  25      Yatin
# emp_2      Delhi  28     Piyush
# emp_3   Dehradun  27     Akshay
# emp_4  Bangalore  24     Yushma
# emp_5    Madurai  28  Vaishnavi

# %%
df
# Out:
#        Name  Age        City
# 0    Tanmay   25        Pune
# 1    Sanjay   24   Bangalore
# 2    Ambika   28     Chennai
# 3       Ebi   22    Dehradun
# 4  Prajakta   26      Mumbai
# 5    Vishal   31        Pune
# 6     Yatin   25  Chandigarh
# 7    Natraj   36       Delhi

# %% [markdown]
# # How to fetch a column

# %%
# Using slicing
# df['col_name']
# df.col_name

# %%
# Fetch the city column

df.loc[::,['City']]
# Out:
#          City
# 0        Pune
# 1   Bangalore
# 2     Chennai
# 3    Dehradun
# 4      Mumbai
# 5        Pune
# 6  Chandigarh
# 7       Delhi

# %%
df[['City']]
# Out:
#          City
# 0        Pune
# 1   Bangalore
# 2     Chennai
# 3    Dehradun
# 4      Mumbai
# 5        Pune
# 6  Chandigarh
# 7       Delhi

# %%
df.City
# Out:
# 0          Pune
# 1     Bangalore
# 2       Chennai
# 3      Dehradun
# 4        Mumbai
# 5          Pune
# 6    Chandigarh
# 7         Delhi
# Name: City, dtype: object

# %%
# Fetch Age and Name columns

df[['Age','Name']]
# Out:
#    Age      Name
# 0   25    Tanmay
# 1   24    Sanjay
# 2   28    Ambika
# 3   22       Ebi
# 4   26  Prajakta
# 5   31    Vishal
# 6   25     Yatin
# 7   36    Natraj

# %%
df.loc[::,['Age','Name']]
# Out:
#    Age      Name
# 0   25    Tanmay
# 1   24    Sanjay
# 2   28    Ambika
# 3   22       Ebi
# 4   26  Prajakta
# 5   31    Vishal
# 6   25     Yatin
# 7   36    Natraj

# %%
# df.Age

# %% [markdown]
# # Adding a new column

# %%
# df['col_name']=value

# %%
df
# Out:
#        Name  Age        City
# 0    Tanmay   25        Pune
# 1    Sanjay   24   Bangalore
# 2    Ambika   28     Chennai
# 3       Ebi   22    Dehradun
# 4  Prajakta   26      Mumbai
# 5    Vishal   31        Pune
# 6     Yatin   25  Chandigarh
# 7    Natraj   36       Delhi

# %%
df['Company']='Infosys'

# %%
df
# Out:
#        Name  Age        City  Company
# 0    Tanmay   25        Pune  Infosys
# 1    Sanjay   24   Bangalore  Infosys
# 2    Ambika   28     Chennai  Infosys
# 3       Ebi   22    Dehradun  Infosys
# 4  Prajakta   26      Mumbai  Infosys
# 5    Vishal   31        Pune  Infosys
# 6     Yatin   25  Chandigarh  Infosys
# 7    Natraj   36       Delhi  Infosys

# %%
df
# Out:
#        Name  Age        City  Company
# 0    Tanmay   25        Pune  Infosys
# 1    Sanjay   24   Bangalore  Infosys
# 2    Ambika   28     Chennai  Infosys
# 3       Ebi   22    Dehradun  Infosys
# 4  Prajakta   26      Mumbai  Infosys
# 5    Vishal   31        Pune  Infosys
# 6     Yatin   25  Chandigarh  Infosys
# 7    Natraj   36       Delhi  Infosys

# %%
df.loc[4:,'Company']='Wipro'

# %%
df
# Out:
#        Name  Age        City  Company
# 0    Tanmay   25        Pune  Infosys
# 1    Sanjay   24   Bangalore  Infosys
# 2    Ambika   28     Chennai  Infosys
# 3       Ebi   22    Dehradun  Infosys
# 4  Prajakta   26      Mumbai    Wipro
# 5    Vishal   31        Pune    Wipro
# 6     Yatin   25  Chandigarh    Wipro
# 7    Natraj   36       Delhi    Wipro

# %% [markdown]
# # How to import a csv or Excel file?

# %%
# pd.read_csv(path)
# pd.read_excel(path)

# %%
pd.read_csv("C:\\Users\\ashis\\OneDrive\\Desktop\\Data Science\\Batches\\Practice Datasets\\Titanic.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.read_csv("C:/Users/ashis/OneDrive/Desktop/Data Science/Batches/Practice Datasets/Titanic.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df=pd.read_csv(r"C:\Users\ashis\OneDrive\Desktop\Data Science\Batches\Practice Datasets\Titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Functions

# %%
# head()
# tail()
# info()
# describe()
# isna()
# innull()
# dropna()
# fillna()
# nunique()
# unique()
# value_counts()
# duplicated()
# drop_duplicates()
# merge()
# groupby()
# pivot_table()

# %% [markdown]
# # head()
# - It returns the first 5 rows of the dataframe

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.head(50)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %%
df.iloc[0:50]
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %% [markdown]
# # tail()
# - It returns the last 5 rows by default

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.tail(50)
# Out:
#      PassengerId  Survived  Pclass  \
# 841          842         0       2
# 842          843         1       1
# 843          844         0       3
# 844          845         0       3
# 845          846         0       3
# 846          847         0       3
# 847          848         0       3
# 848          849         0       2
# 849          850         1       1
# 850          851         0       3
# 851          852         0       3
# 852          853         0       3
# 853          854         1       1
# 854          855         0       2
# 855          856         1       3
# 856          857         1       1
# 857          858         1       1
# 858          859         1       3
# 859          860         0       3
# 860          861         0       3
# 861          862         0       2
# 862          863         1       1
# 863          864         0       3
# 864          865         0       2
# 865          866         1       2
# ...

# %%
df.tail(100)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 791          792         0       2                       Gaskell, Mr. Alfred
# 792          793         0       3                   Sage, Miss. Stella Anna
# 793          794         0       1                  Hoyt, Mr. William Fisher
# 794          795         0       3                     Dantcheff, Mr. Ristiu
# 795          796         0       2                        Otter, Mr. Richard
# ..           ...       ...     ...                                       ...
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
df.iloc[-1:-101:-1][::-1]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 791          792         0       2                       Gaskell, Mr. Alfred
# 792          793         0       3                   Sage, Miss. Stella Anna
# 793          794         0       1                  Hoyt, Mr. William Fisher
# 794          795         0       3                     Dantcheff, Mr. Ristiu
# 795          796         0       2                        Otter, Mr. Richard
# ..           ...       ...     ...                                       ...
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
# print(df.iloc[795:885].to_string())

# %% [markdown]
# # info()
# - It returns a series that contains some basic informration of the dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # describe()
# - It returns a dataframe.
# - It gives the 5 point statistical summary of the numerical columns of a dataframe

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.Age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df.Age.describe(percentiles=[0.01,0.1,0.25,0.50,0.75,0.9,0.95,0.99])
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 1%         1.000000
# 10%       14.000000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# 90%       50.000000
# 95%       56.000000
# 99%       65.870000
# max       80.000000
# Name: Age, dtype: float64

# %% [markdown]
# # nunique()
# - It can be applied on a dataframe only.
# - It returns the number of unique values in each column.

# %%
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
# df.Survived

# %% [markdown]
# # unique()
# - It is applied on a column/series
# - It returns an array that contains the unique values in that particular column.

# %%
df.Survived.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df.Pclass.unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
df.Sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %% [markdown]
# # value_counts()
# - It returns the count of unique values in a column.

# %%
df.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
491+216+184
# Out:
# 891

# %%
df.shape
# Out:
# (891, 12)

# %%
df.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df.Sex.iloc[0:10]=np.nan
# Out:
# C:\Users\ashis\AppData\Local\Temp\ipykernel_16344\3693142408.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Sex.iloc[0:10]=np.nan

# %%
df.Sex.unique()
# Out:
# array([nan, 'female', 'male'], dtype=object)

# %%
df.Sex.value_counts()
# Out:
# male      572
# female    309
# Name: Sex, dtype: int64

# %%
572+309
# Out:
# 881

# %%
df.Sex.value_counts(dropna=False)
# Out:
# male      572
# female    309
# NaN        10
# Name: Sex, dtype: int64

# %%
df.Sex.iloc[0:2]=0
# Out:
# C:\Users\ashis\AppData\Local\Temp\ipykernel_16344\3134182551.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Sex.iloc[0:2]=0

# %%
df.Sex.unique()
# Out:
# array([0, nan, 'female', 'male'], dtype=object)

# %%
df.Sex.value_counts(dropna=False)
# Out:
# male      572
# female    309
# NaN         8
# 0           2
# Name: Sex, dtype: int64

# %% [markdown]
# # Handling the missing values

# %%
# - Check for the missing values.
# - Treat the missing values.

# %% [markdown]
# # Check for the missing values

# %%
# - isna()
# - isnull()

# - Both the above functions return a boolean dataframe

# %%
df.isna()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False   True  False  False  False   False
# 3          False     False   False  False   True  False  False  False   False
# 4          False     False   False  False   True  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False   True  False  False  False   False
# 3          False     False   False  False   True  False  False  False   False
# 4          False     False   False  False   True  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              8
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              8
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # Treatment of the missing values

# %%
# - We can drop the missing values.
# - We can fill the missing value with some other value. (Null value imputation)

# %% [markdown]
# ### Dropping the missing values

# %%
# df.dropna()

# - It drops all the rows that have atleast 1 missing value
# - It returns a new dataframe

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris       0  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...       0  38.0      1
# 2                               Heikkinen, Miss. Laina     NaN  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)     NaN  35.0      1
# 4                             Allen, Mr. William Henry     NaN  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 10            11         1       3
# 11            12         1       1
# 21            22         1       2
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...       0  38.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 21                               Beesley, Mr. Lawrence    male  34.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
891-181
# Out:
# 710

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris       0  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...       0  38.0      1
# 2                               Heikkinen, Miss. Laina     NaN  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)     NaN  35.0      1
# 4                             Allen, Mr. William Henry     NaN  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# df=df.dropna()

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 10            11         1       3
# 11            12         1       1
# 21            22         1       2
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...       0  38.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 21                               Beesley, Mr. Lawrence    male  34.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dd=pd.DataFrame([[10,20,30],[np.nan,50,60],[np.nan,np.nan,np.nan],[np.nan,55,np.nan],[50,60,70],[np.nan,np.nan,np.nan]],columns=['A','B','C'])
dd
# Out:
#       A     B     C
# 0  10.0  20.0  30.0
# 1   NaN  50.0  60.0
# 2   NaN   NaN   NaN
# 3   NaN  55.0   NaN
# 4  50.0  60.0  70.0
# 5   NaN   NaN   NaN

# %%
dd.dropna(inplace=True)

# %%
dd
# Out:
#       A     B     C
# 0  10.0  20.0  30.0
# 4  50.0  60.0  70.0

# %%
dd=pd.DataFrame([[10,20,30],[np.nan,50,60],[np.nan,np.nan,np.nan],[np.nan,55,np.nan],[50,60,70],[np.nan,np.nan,np.nan]],columns=['A','B','C'])
dd
# Out:
#       A     B     C
# 0  10.0  20.0  30.0
# 1   NaN  50.0  60.0
# 2   NaN   NaN   NaN
# 3   NaN  55.0   NaN
# 4  50.0  60.0  70.0
# 5   NaN   NaN   NaN

# %%
dd.dropna(how='all',inplace=True)

# %%
dd.reset_index(inplace=True)

# %%
dd
# Out:
#    index     A     B     C
# 0      0  10.0  20.0  30.0
# 1      1   NaN  50.0  60.0
# 2      3   NaN  55.0   NaN
# 3      4  50.0  60.0  70.0

# %%
dd=pd.DataFrame([[10,20,30],[np.nan,50,60],[np.nan,np.nan,np.nan],[np.nan,55,np.nan],[50,60,70],[np.nan,np.nan,np.nan]],columns=['A','B','C'])
dd
# Out:
#       A     B     C
# 0  10.0  20.0  30.0
# 1   NaN  50.0  60.0
# 2   NaN   NaN   NaN
# 3   NaN  55.0   NaN
# 4  50.0  60.0  70.0
# 5   NaN   NaN   NaN

# %%
dd['New']=np.nan

# %%
dd
# Out:
#       A     B     C  New
# 0  10.0  20.0  30.0  NaN
# 1   NaN  50.0  60.0  NaN
# 2   NaN   NaN   NaN  NaN
# 3   NaN  55.0   NaN  NaN
# 4  50.0  60.0  70.0  NaN
# 5   NaN   NaN   NaN  NaN

# %%
dd.dropna()
# Out:
# Empty DataFrame
# Columns: [A, B, C, New]
# Index: []

# %%
# dropna(how='all')

# %% [markdown]
# # Null value Imputation
# ### (Filling the missing values)

# %% [markdown]
# - It is the better idea than dropping the missing values.
# - We always impute the missing values column wise.
#
# - Generally if the column is a numeric continuous column then we fill the missing values with either mean or median.
# - If the column is a categorical column then we fill the missing values with mode
#
# - **Note-** Any column that has more than 25% values as null values we don't impute the missing values.
# - We drop such column.
