# %%
import pandas as pd

# %% [markdown]
# # Null value Imputation
# ### (Filling the missing values)

# %% [markdown]
# - It is the better idea than dropping the missing values.
# - We always impute the missing values column wise.
#
# - Generally if the column is a numeric continuous column then we fill the missing values with either mean or median.
# - If the column is a categorical column then we fill the missing values with mode
#
# - **Note-** Any column that has more than 25% values as null values we don't impute the missing values.
# - We drop such column.

# %% [markdown]
# # fillna()

# %%
# - It is used to fill the missing values in a dataframe or in a column
# - df.col_name.fillna(value)

# %%
df=pd.read_csv("C:\\Users\\ashis\\OneDrive\\Desktop\\Data Science\\Batches\\Practice Datasets\\Titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Numeric Continuous- Age, Height, Weight, Income, Population.
# Categorical- Gender, Eductaion, A few unique values

# %%
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# ### Age

# %%
# Let's fill with mean

# %%
df.Age.mean()
# Out:
# 29.69911764705882

# %%
df.Age.fillna(df.Age.mean())
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# df.Age=df.Age.fillna(df.Age.mean())
df.Age.fillna(df.Age.mean(),inplace=True)

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ### Cabin

# %%
df.isna().sum()*100/len(df)
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age             0.000000
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
687*100/891
# Out:
# 77.10437710437711

# %%
len(df)
# Out:
# 891

# %%
# We should drop Cabin column

# %% [markdown]
# ### Embarked

# %%
df.Embarked
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
# Let's fill with mode

# %%
df.Embarked.mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
df.Embarked.mode()[0]
# Out:
# 'S'

# %%
df.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df.Embarked.fillna(df.Embarked.mode()[0],inplace=True)

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %% [markdown]
# # Dropping a column

# %%
# df.drop('col_name',axis=1)
# df.drop(columns=['col_name','col_name'])

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Let's drop Cabin column

# %%
df.drop('Cabin',axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# 886                              Montvila, Rev. Juozas    male  27.000000
# 887                       Graham, Miss. Margaret Edith  female  19.000000
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  29.699118
# 889                              Behr, Mr. Karl Howell    male  26.000000
# 890                                Dooley, Mr. Patrick    male  32.000000
#
#      SibSp  Parch            Ticket     Fare Embarked
# 0        1      0         A/5 21171   7.2500        S
# 1        1      0          PC 17599  71.2833        C
# 2        0      0  STON/O2. 3101282   7.9250        S
# 3        1      0            113803  53.1000        S
# 4        0      0            373450   8.0500        S
# ..     ...    ...               ...      ...      ...
# 886      0      0            211536  13.0000        S
# 887      0      0            112053  30.0000        S
# 888      1      2        W./C. 6607  23.4500        S
# 889      0      0            111369  30.0000        C
# 890      0      0            370376   7.7500        Q
#
# [891 rows x 11 columns]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.drop(columns=['Cabin'])
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# 886                              Montvila, Rev. Juozas    male  27.000000
# 887                       Graham, Miss. Margaret Edith  female  19.000000
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  29.699118
# 889                              Behr, Mr. Karl Howell    male  26.000000
# 890                                Dooley, Mr. Patrick    male  32.000000
#
#      SibSp  Parch            Ticket     Fare Embarked
# 0        1      0         A/5 21171   7.2500        S
# 1        1      0          PC 17599  71.2833        C
# 2        0      0  STON/O2. 3101282   7.9250        S
# 3        1      0            113803  53.1000        S
# 4        0      0            373450   8.0500        S
# ..     ...    ...               ...      ...      ...
# 886      0      0            211536  13.0000        S
# 887      0      0            112053  30.0000        S
# 888      1      2        W./C. 6607  23.4500        S
# 889      0      0            111369  30.0000        C
# 890      0      0            370376   7.7500        Q
#
# [891 rows x 11 columns]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# df=df.drop('Cabin',axis=1)
df.drop('Cabin',axis=1,inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
# Drop- PassengerID, Name,Ticket columns

# %%
df.drop(['Ticket','Name','PassengerId'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %% [markdown]
# # Renaming a column

# %%
# df.rename({'col_name_1':'new_name','col_name_2':'new_name'})

# %%
# Sex- Gender, sibSp- Siblings, Parch- Parents

# %%
df.rename({'Sex':'Gender','SibSp':'Siblings','Parch':'Parents'},axis=1)
# Out:
#      Survived  Pclass  Gender        Age  Siblings  Parents     Fare Embarked
# 0           0       3    male  22.000000         1        0   7.2500        S
# 1           1       1  female  38.000000         1        0  71.2833        C
# 2           1       3  female  26.000000         0        0   7.9250        S
# 3           1       1  female  35.000000         1        0  53.1000        S
# 4           0       3    male  35.000000         0        0   8.0500        S
# ..        ...     ...     ...        ...       ...      ...      ...      ...
# 886         0       2    male  27.000000         0        0  13.0000        S
# 887         1       1  female  19.000000         0        0  30.0000        S
# 888         0       3  female  29.699118         1        2  23.4500        S
# 889         1       1    male  26.000000         0        0  30.0000        C
# 890         0       3    male  32.000000         0        0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
df.rename({'Sex':'Gender','SibSp':'Siblings','Parch':'Parents'},axis=1,inplace=True)

# %%
df.head()
# Out:
#    Survived  Pclass  Gender   Age  Siblings  Parents     Fare Embarked
# 0         0       3    male  22.0         1        0   7.2500        S
# 1         1       1  female  38.0         1        0  71.2833        C
# 2         1       3  female  26.0         0        0   7.9250        S
# 3         1       1  female  35.0         1        0  53.1000        S
# 4         0       3    male  35.0         0        0   8.0500        S

# %% [markdown]
# # Dropping the rows

# %%
# Drop 0th,1st and 4th rows

# %%
df.drop([0,1,5],inplace=True)

# %%
df.reset_index()
# Out:
#      index  Survived  Pclass  Gender        Age  Siblings  Parents     Fare  \
# 0        2         1       3  female  26.000000         0        0   7.9250
# 1        3         1       1  female  35.000000         1        0  53.1000
# 2        4         0       3    male  35.000000         0        0   8.0500
# 3        6         0       1    male  54.000000         0        0  51.8625
# 4        7         0       3    male   2.000000         3        1  21.0750
# ..     ...       ...     ...     ...        ...       ...      ...      ...
# 883    886         0       2    male  27.000000         0        0  13.0000
# 884    887         1       1  female  19.000000         0        0  30.0000
# 885    888         0       3  female  29.699118         1        2  23.4500
# 886    889         1       1    male  26.000000         0        0  30.0000
# 887    890         0       3    male  32.000000         0        0   7.7500
#
#     Embarked
# 0          S
# 1          S
# 2          S
# 3          S
# 4          S
# ..       ...
# 883        S
# 884        S
# 885        S
# 886        C
# 887        Q
#
# [888 rows x 9 columns]

# %%
df.head()
# Out:
#    Survived  Pclass  Gender   Age  Siblings  Parents     Fare Embarked
# 2         1       3  female  26.0         0        0   7.9250        S
# 3         1       1  female  35.0         1        0  53.1000        S
# 4         0       3    male  35.0         0        0   8.0500        S
# 6         0       1    male  54.0         0        0  51.8625        S
# 7         0       3    male   2.0         3        1  21.0750        S

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#    index  Survived  Pclass  Gender   Age  Siblings  Parents     Fare Embarked
# 0      2         1       3  female  26.0         0        0   7.9250        S
# 1      3         1       1  female  35.0         1        0  53.1000        S
# 2      4         0       3    male  35.0         0        0   8.0500        S
# 3      6         0       1    male  54.0         0        0  51.8625        S
# 4      7         0       3    male   2.0         3        1  21.0750        S

# %% [markdown]
# # Inserting a row or a column at a particuular index

# %%
# df['Dummy']=np.nan

# %%
# df.insert(index,column_name,value)

# %%
s=pd.Series([i for i in range(1,889)])
s
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 883    884
# 884    885
# 885    886
# 886    887
# 887    888
# Length: 888, dtype: int64

# %%
df.insert(loc=2,column='Dummy_2',value=s)

# %%
df
# Out:
#      index  Survived  Dummy_2  Dummy  Pclass  Gender        Age  Siblings  \
# 0        2         1        1      1       3  female  26.000000         0
# 1        3         1        2      2       1  female  35.000000         1
# 2        4         0        3      3       3    male  35.000000         0
# 3        6         0        4      4       1    male  54.000000         0
# 4        7         0        5      5       3    male   2.000000         3
# ..     ...       ...      ...    ...     ...     ...        ...       ...
# 883    886         0      884    884       2    male  27.000000         0
# 884    887         1      885    885       1  female  19.000000         0
# 885    888         0      886    886       3  female  29.699118         1
# 886    889         1      887    887       1    male  26.000000         0
# 887    890         0      888    888       3    male  32.000000         0
#
#      Parents     Fare Embarked
# 0          0   7.9250        S
# 1          0  53.1000        S
# 2          0   8.0500        S
# 3          0  51.8625        S
# 4          1  21.0750        S
# ..       ...      ...      ...
# 883        0  13.0000        S
# 884        0  30.0000        S
# 885        2  23.4500        S
# 886        0  30.0000        C
# 887        0   7.7500        Q
#
# [888 rows x 11 columns]

# %%
# help(df.insert)

# %% [markdown]
# # Rearrange the columns

# %%
df[['Siblings','Pclass','Fare','Age','Gender']].head()
# Out:
#    Siblings  Pclass     Fare   Age  Gender
# 0         0       3   7.9250  26.0  female
# 1         1       1  53.1000  35.0  female
# 2         0       3   8.0500  35.0    male
# 3         0       1  51.8625  54.0    male
# 4         3       3  21.0750   2.0    male

# %% [markdown]
# # Data filteration

# %% [markdown]
# # Sorting

# %%
# df.sort_values(by=col_name)

# %%
df.sort_values(by='Age')
# Out:
#      index  Survived  Dummy_2  Dummy  Pclass  Gender    Age  Siblings  \
# 800    803         1      801    801       3    male   0.42         0
# 752    755         1      753    753       2    male   0.67         1
# 641    644         1      642    642       3  female   0.75         2
# 466    469         1      467    467       3  female   0.75         2
# 828    831         1      829    829       2    male   0.83         1
# ..     ...       ...      ...    ...     ...     ...    ...       ...
# 113    116         0      114    114       3    male  70.50         0
# 93      96         0       94     94       1    male  71.00         0
# 490    493         0      491    491       1    male  71.00         0
# 848    851         0      849    849       3    male  74.00         0
# 627    630         1      628    628       1    male  80.00         0
#
#      Parents     Fare Embarked
# 800        1   8.5167        C
# 752        1  14.5000        S
# 641        1  19.2583        C
# 466        1  19.2583        C
# 828        1  18.7500        S
# ..       ...      ...      ...
# 113        0   7.7500        Q
# 93         0  34.6542        C
# 490        0  49.5042        C
# 848        0   7.7750        S
# 627        0  30.0000        S
#
# [888 rows x 11 columns]

# %%
df.sort_values(by='Age',ascending=False)
# Out:
#      index  Survived  Dummy_2  Dummy  Pclass  Gender    Age  Siblings  \
# 627    630         1      628    628       1    male  80.00         0
# 848    851         0      849    849       3    male  74.00         0
# 490    493         0      491    491       1    male  71.00         0
# 93      96         0       94     94       1    male  71.00         0
# 113    116         0      114    114       3    male  70.50         0
# ..     ...       ...      ...    ...     ...     ...    ...       ...
# 75      78         1       76     76       2    male   0.83         0
# 466    469         1      467    467       3  female   0.75         2
# 641    644         1      642    642       3  female   0.75         2
# 752    755         1      753    753       2    male   0.67         1
# 800    803         1      801    801       3    male   0.42         0
#
#      Parents     Fare Embarked
# 627        0  30.0000        S
# 848        0   7.7750        S
# 490        0  49.5042        C
# 93         0  34.6542        C
# 113        0   7.7500        Q
# ..       ...      ...      ...
# 75         2  29.0000        S
# 466        1  19.2583        C
# 641        1  19.2583        C
# 752        1  14.5000        S
# 800        1   8.5167        C
#
# [888 rows x 11 columns]

# %%
# Sort according to Age and Gender

df.sort_values(by=['Gender','Age'],ascending=False)
# Out:
#      index  Survived  Dummy_2  Dummy  Pclass  Gender    Age  Siblings  \
# 627    630         1      628    628       1    male  80.00         0
# 848    851         0      849    849       3    male  74.00         0
# 93      96         0       94     94       1    male  71.00         0
# 490    493         0      491    491       1    male  71.00         0
# 113    116         0      114    114       3    male  70.50         0
# ..     ...       ...      ...    ...     ...     ...    ...       ...
# 639    642         0      640    640       3  female   2.00         3
# 169    172         1      170    170       3  female   1.00         1
# 378    381         1      379    379       3  female   1.00         0
# 466    469         1      467    467       3  female   0.75         2
# 641    644         1      642    642       3  female   0.75         2
#
#      Parents     Fare Embarked
# 627        0  30.0000        S
# 848        0   7.7750        S
# 93         0  34.6542        C
# 490        0  49.5042        C
# 113        0   7.7500        Q
# ..       ...      ...      ...
# 639        2  27.9000        S
# 169        1  11.1333        S
# 378        2  15.7417        C
# 466        1  19.2583        C
# 641        1  19.2583        C
#
# [888 rows x 11 columns]

# %% [markdown]
# # Conditions

# %%
# Fetch the data of male passengers

# %%
df[df.Gender=='male']
# Out:
#      index  Survived  Dummy_2  Dummy  Pclass Gender   Age  Siblings  Parents  \
# 2        4         0        3      3       3   male  35.0         0        0
# 3        6         0        4      4       1   male  54.0         0        0
# 4        7         0        5      5       3   male   2.0         3        1
# 9       12         0       10     10       3   male  20.0         0        0
# 10      13         0       11     11       3   male  39.0         1        5
# ..     ...       ...      ...    ...     ...    ...   ...       ...      ...
# 880    883         0      881    881       2   male  28.0         0        0
# 881    884         0      882    882       3   male  25.0         0        0
# 883    886         0      884    884       2   male  27.0         0        0
# 886    889         1      887    887       1   male  26.0         0        0
# 887    890         0      888    888       3   male  32.0         0        0
#
#         Fare Embarked
# 2     8.0500        S
# 3    51.8625        S
# 4    21.0750        S
# 9     8.0500        S
# 10   31.2750        S
# ..       ...      ...
# 880  10.5000        S
# 881   7.0500        S
# 883  13.0000        S
# 886  30.0000        C
# 887   7.7500        Q
#
# [575 rows x 11 columns]

# %%
# Get the Age of Female passengers

# %%
df[df.Gender=='female'][['Age','Gender','Fare','Parents']]
# Out:
#            Age  Gender     Fare  Parents
# 0    26.000000  female   7.9250        0
# 1    35.000000  female  53.1000        0
# 5    27.000000  female  11.1333        2
# 6    14.000000  female  30.0708        0
# 7     4.000000  female  16.7000        1
# ..         ...     ...      ...      ...
# 877  25.000000  female  26.0000        1
# 879  22.000000  female  10.5167        0
# 882  39.000000  female  29.1250        5
# 884  19.000000  female  30.0000        0
# 885  29.699118  female  23.4500        2
#
# [313 rows x 4 columns]

# %%
# Male passengers travelling in Pclass 3

# %%
df[(df.Pclass==3)&(df.Gender=='male')]
# Out:
#      index  Survived  Dummy_2  Dummy  Pclass Gender        Age  Siblings  \
# 2        4         0        3      3       3   male  35.000000         0
# 4        7         0        5      5       3   male   2.000000         3
# 9       12         0       10     10       3   male  20.000000         0
# 10      13         0       11     11       3   male  39.000000         1
# 13      16         0       14     14       3   male   2.000000         4
# ..     ...       ...      ...    ...     ...    ...        ...       ...
# 874    877         0      875    875       3   male  19.000000         0
# 875    878         0      876    876       3   male  29.699118         0
# 878    881         0      879    879       3   male  33.000000         0
# 881    884         0      882    882       3   male  25.000000         0
# 887    890         0      888    888       3   male  32.000000         0
#
#      Parents     Fare Embarked
# 2          0   8.0500        S
# 4          1  21.0750        S
# 9          0   8.0500        S
# 10         5  31.2750        S
# 13         1  29.1250        Q
# ..       ...      ...      ...
# 874        0   7.8958        S
# 875        0   7.8958        S
# 878        0   7.8958        S
# 881        0   7.0500        S
# 887        0   7.7500        Q
#
# [345 rows x 11 columns]

# %%
df.Gender=='male'
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 883     True
# 884    False
# 885    False
# 886     True
# 887     True
# Name: Gender, Length: 888, dtype: bool

# %%
# Average Fare of the male passengers travelling in Pclass 3

# %%
df[(df.Gender=='male')&(df.Pclass==3)]['Fare'].mean()
# Out:
# 12.689502028985505

# %%
# Average Fare of the female passengers travelling in Pclass 1

# %%
df[(df.Gender=='female')&(df.Pclass==1)]['Fare'].mean()
# Out:
# 106.50044838709677

# %%
# Make the Fare 0 for the passengers who are male and more than 60 years old and travelling in Pclass 3

# %%
# df[(df.Gender=='male')&(df.Age>60)&(df.Pclass==3)]['Fare']=0

# %%
df.loc[(df.Gender=='male')&(df.Age>60)&(df.Pclass==3),'Fare']=0

# %%
df[(df.Gender=='male')&(df.Age>60)&(df.Pclass==3)]
# Out:
#      index  Survived  Dummy_2  Dummy  Pclass Gender   Age  Siblings  Parents  \
# 113    116         0      114    114       3   male  70.5         0        0
# 277    280         0      278    278       3   male  65.0         0        0
# 323    326         0      324    324       3   male  61.0         0        0
# 848    851         0      849    849       3   male  74.0         0        0
#
#      Fare Embarked
# 113   0.0        Q
# 277   0.0        Q
# 323   0.0        S
# 848   0.0        S

# %% [markdown]
# # groupby()

# %%
# - It is used to analyse 2 or more columns together.
# - It returns a Series

# %%
# df.groupby('col_name').col_name.function()

# %%
# Average Age of Female and Male Passengers

# Gender
# Age
# Operation- mean (Age)

# %%
df.groupby('Gender').Age.mean()
# Out:
# Gender
# female    28.185474
# male      30.522020
# Name: Age, dtype: float64

# %%
# Average Age of Male and Female passengers in each Pclass

# Age
# Gender
# Pclass

# Operation- mean (Age)

# %%
df.groupby(['Gender','Pclass']).Age.mean()
# Out:
# Gender  Pclass
# female  1         34.099915
#         2         28.748661
#         3         24.068493
# male    1         39.287717
#         2         30.653908
#         3         27.380980
# Name: Age, dtype: float64

# %%
pd.DataFrame(df.groupby(['Pclass','Gender']).Age.mean())
# Out:
#                      Age
# Pclass Gender
# 1      female  34.099915
#        male    39.287717
# 2      female  28.748661
#        male    30.653908
# 3      female  24.068493
#        male    27.380980

# %%
df.groupby(['Gender','Pclass']).Age.max()
# Out:
# Gender  Pclass
# female  1         63.0
#         2         57.0
#         3         63.0
# male    1         80.0
#         2         70.0
#         3         74.0
# Name: Age, dtype: float64

# %% [markdown]
# # Pivot Table

# %%
# - It is used to summarise the data.
# - It returns a dataframe

# %%
# pd.pivot_table(df,index,values,columns,aggfunc=)

# %%
ss=pd.read_excel(r"C:\Users\ashis\OneDrive\Desktop\Data Science\Batches\Practice Datasets\sales.xlsx")
ss.head()
# Out:
#    Year    Month           Type Salesperson Region    Sales  Units  Order #
# 0  2013  January      Ice Cream      Bishop   West   2395.5   1597        1
# 1  2013  January      Ice Cream      Bishop   West  11761.5   7841        2
# 2  2013  January  Frozen Yogurt      Bishop   West   8943.0   5962        3
# 3  2013  January      Ice Cream      Bishop   West   2395.5   1597        4
# 4  2013  January      Ice Cream      Bishop   West  11761.5   7841        5

# %%
# Region wise total sale

# Region
# Sales
# Operation- sum (Sales)

# %%
ss.groupby('Region').Sales.sum()
# Out:
# Region
# Central    280674.0
# North       72741.0
# South       21321.0
# West       138600.0
# Name: Sales, dtype: float64

# %%
pd.pivot_table(ss,index='Region',values='Sales',aggfunc='sum')
# Out:
#             Sales
# Region
# Central  280674.0
# North     72741.0
# South     21321.0
# West     138600.0

# %%
pd.pivot_table(ss,columns='Region',values='Sales',aggfunc='sum')
# Out:
# Region   Central    North    South      West
# Sales   280674.0  72741.0  21321.0  138600.0

# %%
# Region wise total sales of each Type

# Region
# Type
# Sales

# Operation- sum (Sales)

# %%
pd.pivot_table(ss,index='Region',columns='Type',values='Sales',aggfunc=sum,fill_value=0)
# Out:
# Type     Frozen Yogurt  Ice Cream  Popsicles  Tasty Treats
# Region
# Central         175158          0          0        105516
# North                0      72741          0             0
# South                0          0      21321             0
# West             53658      84942          0             0

# %%
pd.pivot_table(ss,columns='Region',index='Type',values='Sales',aggfunc=sum,fill_value=0)
# Out:
# Region         Central  North  South   West
# Type
# Frozen Yogurt   175158      0      0  53658
# Ice Cream            0  72741      0  84942
# Popsicles            0      0  21321      0
# Tasty Treats    105516      0      0      0

# %%
pd.pivot_table(ss,index=['Region','Type'],values='Sales',aggfunc=sum,fill_value=0)
# Out:
#                         Sales
# Region  Type
# Central Frozen Yogurt  175158
#         Tasty Treats   105516
# North   Ice Cream       72741
# South   Popsicles       21321
# West    Frozen Yogurt   53658
#         Ice Cream       84942

# %%
pd.pivot_table(ss,columns=['Region','Type'],values='Sales',aggfunc=sum,fill_value=0)
# Out:
# Region       Central                  North     South          West
# Type   Frozen Yogurt Tasty Treats Ice Cream Popsicles Frozen Yogurt Ice Cream
# Sales         175158       105516     72741     21321         53658     84942

# %%
# Region wise Total sale and the average sales and the maximum sales

pd.pivot_table(ss,index='Region',values='Sales',aggfunc=['sum','mean','max'])
# Out:
#               sum      mean      max
#             Sales     Sales    Sales
# Region
# Central  280674.0  11694.75  14596.5
# North     72741.0   6061.75   7318.5
# South     21321.0   3553.50   3553.5
# West     138600.0   7700.00  11761.5

# %%
# Region wise Total sale and the average sales and the maximum sales and the same for the number of units sold

# %%
pd.pivot_table(ss,index='Region',values=['Sales','Units'],aggfunc=['sum','mean','max'])
# Out:
#               sum              mean                   max
#             Sales   Units     Sales        Units    Sales Units
# Region
# Central  280674.0  187116  11694.75  7796.500000  14596.5  9731
# North     72741.0   63012   6061.75  5251.000000   7318.5  5623
# South     21321.0   14214   3553.50  2369.000000   3553.5  2369
# West     138600.0   92400   7700.00  5133.333333  11761.5  7841

# %%
pp=pd.pivot_table(ss,index='Region',columns='Type',values=['Sales','Units'],aggfunc=['sum','mean','max'],fill_value=0)
pp
# Out:
#                   sum                                                 \
#                 Sales                                          Units
# Type    Frozen Yogurt Ice Cream Popsicles Tasty Treats Frozen Yogurt
# Region
# Central        175158         0         0       105516        116772
# North               0     72741         0            0             0
# South               0         0     21321            0             0
# West            53658     84942         0            0         35772
#
#                                                   mean            ...  \
#                                                  Sales            ...
# Type    Ice Cream Popsicles Tasty Treats Frozen Yogurt Ice Cream  ...
# Region                                                            ...
# Central         0         0        70344       14596.5      0.00  ...
# North       63012         0            0           0.0   6061.75  ...
# South           0     14214            0           0.0      0.00  ...
# West        56628         0            0        8943.0   7078.50  ...
#
#                                          max                                   \
#             Units                      Sales
# Type    Popsicles Tasty Treats Frozen Yogurt Ice Cream Popsicles Tasty Treats
# Region
# Central         0         5862       14596.5       0.0       0.0         8793
# North           0            0           0.0    7318.5       0.0            0
# South        2369            0           0.0       0.0    3553.5            0
# West            0            0        8943.0   11761.5       0.0            0
#
#
#                 Units
# Type    Frozen Yogurt Ice Cream Popsicles Tasty Treats
# Region
# Central          9731         0         0         5862
# North               0      5623         0            0
# South               0         0      2369            0
# West             5962      7841         0            0
#
# [4 rows x 24 columns]

# %%
pp.loc[['Central','West']][['sum']]
# Out:
#                   sum                                                 \
#                 Sales                                          Units
# Type    Frozen Yogurt Ice Cream Popsicles Tasty Treats Frozen Yogurt
# Region
# Central        175158         0         0       105516        116772
# West            53658     84942         0            0         35772
#
#
#
# Type    Ice Cream Popsicles Tasty Treats
# Region
# Central         0         0        70344
# West        56628         0            0

# %%
import numpy as np

# %%
pd.pivot_table(ss,index='Region',values='Sales',aggfunc=[np.sum,np.std,np.median,np.var])
# Out:
#               sum          std    median           var
#             Sales        Sales     Sales         Sales
# Region
# Central  280674.0  2964.160366  11694.75  8.786247e+06
# North     72741.0  1332.553146   6409.25  1.775698e+06
# South     21321.0     0.000000   3553.50  0.000000e+00
# West     138600.0  4037.116829   8943.00  1.629831e+07

# %%
# merge()
# agg()
# Regex on a dataframe
# Data Trasnformation

# %%
# hashable- Immutable types (Tuple, Frozenset, String)
# unhashable- Mutable- (List,Dictionary,Set)

# %%
a=10

# %%
hash(a)
# Out:
# 10

# %%
lst=[1,2,3,4,5]
hash(lst)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[219], line 2
#       1 lst=[1,2,3,4,5]
# ----> 2 hash(lst)
#
# TypeError: unhashable type: 'list'

# %%
# ML Algorithm
